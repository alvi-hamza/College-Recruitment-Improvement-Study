# %%
#Questions to Explore
#What was the most contributing event that student was involved at the County College of Morris and/or with
#the Department of Information Technologies prior to enrollling in CCM?
#Also I would like to see that pursuing a specific program is related to a past experience that made student
#enroll in Computer Science or any specific motivation related to a program?
#Are their specific age range that is mostly assoociated with a past experience and program
#What past expireiences does drive student to pursue a computer major/certificate?
#Which major students mostly pursue computer sciecne courses?

# %%
import pandas as pd
import math
import statistics as stats

# %%
import pandas as pd
mydata= pd.read_csv("C:/Users/Hamza/Downloads/new_entry_survey.csv")

# %%
#read some columns
mydata.columns
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?',
#        'How did you hear about County College of Morris? [CCM Web site]',
#        'How did you hear about County College of Morris? [Social Media]',
#        'How did you hear about County College of Morris? [Community Event]',
#        'How did you hear about County College of Morris? [Family member or friend]',
#        'How did you hear about County College of Morris? [Current CCM student]',
#        'How did you hear about County College of Morris? [CCM Alumni]',
#        'How did you hear about County College of Morris? [High School Teacher]',
#        'How did you hear about County College of Morris? [High School Counselor]',
#        'How did you hear about County College of Morris? [In-app advertisement]',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
# ...

# %%
#change the of few columns
mydata_rename = mydata.rename(columns={'How did you hear about County College of Morris? [CCM Web site]': 'Marketed Channel (CCM Website)',
                                       'How did you hear about County College of Morris? [Social Media]': 'Marketed Channel (Social Media)',
                                       'How did you hear about County College of Morris? [Community Event]': 'Marketed Channel (Community Event)',
                                       'How did you hear about County College of Morris? [Current CCM student]':'Marketed Channel (Current CCM student)',
                                       'How did you hear about County College of Morris? [Family member or friend]':'Marketed Channel (Family member or friend)',
                                       'How did you hear about County College of Morris? [CCM Alumni]':'Marketed Channel (CCM alumni)',
                                       'How did you hear about County College of Morris? [High School Teacher]':'Marketed Channel (High School Teacher)',
                                       'How did you hear about County College of Morris? [High School Counselor]':'Marketed Channel (High School Counselor)',
                                       'How did you hear about County College of Morris? [In-app advertisement]':'Marketed Channel (In-app advertisement)',
                                
                                      }
                                       )

# %%
#change the marketing style name first assigning the change to a variable then put in the formula
new_column_names = {
    'To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]': 'Impact (Affordable Cost)',
    'To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]': 'Impact (Location/Convenience)',
    'To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]': 'Impact (Choice of Programs)',
    'To what extent did the following impact your decision to attend County College of Morris? [Online offerings]': 'Impact (Online Offerings)',
    'To what extent did the following impact your decision to attend County College of Morris? [Family/friend referral]': 'Impact (Family/Friend Referral)',
    'To what extent did the following impact your decision to attend County College of Morris? [Faculty/staff]': 'Impact (Faculty/Staff)',
    'To what extent did the following impact your decision to attend County College of Morris? [College reputation]': 'Impact (College Reputation)',
    'To what extent did the following impact your decision to attend County College of Morris? [Financial Aid]': 'Impact (Financial Aid)',
    'To what extent did the following impact your decision to attend County College of Morris? [Scholarships]': 'Impact (Scholarships)',
    'To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]': 'Impact (Small Class Sizes)',
    'To what extent did the following impact your decision to attend County College of Morris? [Extra-curricular opportunities]': 'Impact (Extra-curricular Opportunities)',
    'To what extent did the following impact your decision to attend County College of Morris? [Accepted my transfer credits]': 'Impact (Accepted Transfer Credits)',
    'To what extent did the following impact your decision to attend County College of Morris? [Negative experience at another college]': 'Impact (Negative Experience at Another College)',
    'To what extent did the following impact your decision to attend County College of Morris? [NJ Stars Program]': 'Impact (NJ Stars Program)',
    'To what extent did the following impact your decision to attend County College of Morris? [Ability to transfer CCM credits to a 4-year school]': 'Impact (Transfer CCM Credits)',
    'To what extent did the following impact your decision to attend County College of Morris? [Get college credit while in high school]': 'Impact (College Credit in High School)'
}

mydata_rename.rename(columns=new_column_names, inplace=True)
mydata_rename.columns
# Out:
# Index(['Timestamp', 'Which course are you enrolled in?',
#        'Marketed Channel (CCM Website)', 'Marketed Channel (Social Media)',
#        'Marketed Channel (Community Event)',
#        'Marketed Channel (Family member or friend)',
#        'Marketed Channel (Current CCM student)',
#        'Marketed Channel (CCM alumni)',
#        'Marketed Channel (High School Teacher)',
#        'Marketed Channel (High School Counselor)',
#        'Marketed Channel (In-app advertisement)',
#        'How did you hear about County College of Morris? [Employer]',
#        'How did you hear about County College of Morris? [Billboard]',
#        'How did you hear about County College of Morris? [Television]',
#        'How did you hear about County College of Morris? [Radio]',
#        'How did you hear about County College of Morris? [Home mailer]',
#        'How did you hear about County College of Morris? [Other]',
#        'Impact (Affordable Cost)', 'Impact (Location/Convenience)',
# ...

# %%
# change the influence questions name
new_column_names = {
    'To what extent did the following impact your decision to attend County College of Morris? [Affordable cost]': 'Impact (Affordable Cost)',
    'To what extent did the following impact your decision to attend County College of Morris? [Location/convenience]': 'Impact (Location/Convenience)',
    'To what extent did the following impact your decision to attend County College of Morris? [Choice of programs]': 'Impact (Choice of Programs)',
    'To what extent did the following impact your decision to attend County College of Morris? [Online offerings]': 'Impact (Online Offerings)',
    'To what extent did the following impact your decision to attend County College of Morris? [Family/friend referral]': 'Impact (Family/Friend Referral)',
    'To what extent did the following impact your decision to attend County College of Morris? [Faculty/staff]': 'Impact (Faculty/Staff)',
    'To what extent did the following impact your decision to attend County College of Morris? [College reputation]': 'Impact (College Reputation)',
    'To what extent did the following impact your decision to attend County College of Morris? [Financial Aid]': 'Impact (Financial Aid)',
    'To what extent did the following impact your decision to attend County College of Morris? [Scholarships]': 'Impact (Scholarships)',
    'To what extent did the following impact your decision to attend County College of Morris? [Small class sizes]': 'Impact (Small Class Sizes)',
    'To what extent did the following impact your decision to attend County College of Morris? [Extra-curricular opportunities]': 'Impact (Extra-curricular Opportunities)',
    'To what extent did the following impact your decision to attend County College of Morris? [Accepted my transfer credits]': 'Impact (Accepted Transfer Credits)',
    'To what extent did the following impact your decision to attend County College of Morris? [Negative experience at another college]': 'Impact (Negative Experience at Another College)',
    'To what extent did the following impact your decision to attend County College of Morris? [NJ Stars Program]': 'Impact (NJ Stars Program)',
    'To what extent did the following impact your decision to attend County College of Morris? [Ability to transfer CCM credits to a 4-year school]': 'Impact (Transfer CCM Credits)',
    'To what extent did the following impact your decision to attend County College of Morris? [Get college credit while in high school]': 'Impact (College Credit in High School)',
    'How did you hear about County College of Morris? [Employer]': 'How You Heard (Employer)',
    'How did you hear about County College of Morris? [Billboard]': 'How You Heard (Billboard)',
    'How did you hear about County College of Morris? [Television]': 'How You Heard (Television)',
    'How did you hear about County College of Morris? [Radio]': 'How You Heard (Radio)',
    'How did you hear about County College of Morris? [Home mailer]': 'How You Heard (Home Mailer)',
    'How did you hear about County College of Morris? [Other]': 'How You Heard (Other)'
}

mydata_rename.rename(columns=new_column_names, inplace=True)

# %%
#change scale, motivation, major change column name
new_column_names = {
    'What motivated you to seek a computing degree/certificate at CCM?  [To get a job in the computing field]': 'Motivation (To Get a Job in Computing Field)',
    'What motivated you to seek a computing degree/certificate at CCM?  [Transfer to bachelor\'s level program]': 'Motivation (Transfer to Bachelor\'s Level Program)',
    'What motivated you to seek a computing degree/certificate at CCM?  [Transfer credits back to HS degree (ShareTime, Challenger Program)]': 'Motivation (Transfer Credits Back to HS Degree)',
    'What motivated you to seek a computing degree/certificate at CCM?  [Career Advancement]': 'Motivation (Career Advancement)',
    'What motivated you to seek a computing degree/certificate at CCM?  [Career Change]': 'Motivation (Career Change)',
    'What motivated you to seek a computing degree/certificate at CCM?  [Professional Development]': 'Motivation (Professional Development)',
    'What motivated you to seek a computing degree/certificate at CCM?  [Job Displacement]': 'Motivation (Job Displacement)',
    'What motivated you to seek a computing degree/certificate at CCM?  [Relocation]': 'Motivation (Relocation)',
    'What motivated you to seek a computing degree/certificate at CCM?  [To keep current in tech industry]': 'Motivation (Keep Current in Tech Industry)',
    'What motivated you to seek a computing degree/certificate at CCM?  [IT Industry Certifications]': 'Motivation (IT Industry Certifications)',
    'What motivated you to seek a computing degree/certificate at CCM?  [Financial]': 'Motivation (Financial)',
    'What motivated you to seek a computing degree/certificate at CCM?  [Personal Enrichment]': 'Motivation (Personal Enrichment)',
    'Was a computing major/certificate your first choice, or did you change majors from a different CCM program? If you changed majors, indicate what your first major was.': 'Major',
    'On a scale of 1 to 5, with 1 being not at all interested and 5 being extremely interested, how interested are you in taking more computing classes?': 'Scale'
}

mydata_rename.rename(columns=new_column_names, inplace=True)

# %%
#look at the responses in this column to see how many unique responses are there
mydata_rename['Major'].unique()
# Out:
# array(['First Choice', nan, 'Business', 'Nursing', 'LIberal Arts',
#        'Science', 'did not swap',
#        'Math & Science -> Psychology -> Liberal Arts -> IT',
#        'Engineering', 'Radiography', 'History', 'not majoring',
#        'Criminal Justice ',
#        'I wanted to do computer science but changed to certificate for financial reasons.',
#        'used to be comp sci then switched to IT', 'Game Development',
#        'i did not change', 'I did not change my major',
#        'Criminal Justice', 'Architecture Program', 'Computer Science',
#        'Photography', 'no', 'Computer programming',
#        'changed from wanting to coach to IT',
#        'I have a degree, but wanted to attend ccm courses to get more experience with data analytics',
#        'Math', 'none', 'EDAM sharetime', 'first choice', 'Biology',
#        'cybersecurity ', 'Mechanical Engineering', 'Game Design',
#        'Still majoring in engineering', 'Exercise Science', 'esl',
# ...

# %%
#condense the majors by replacing the phrases with words from unique responses
major = {
    'nan': 'Unknown',
    'LIberal Arts': 'Soicial Science',
    'did not swap': 'Computer Science',
    'Math & Science -> Psychology -> Liberal Arts -> IT': 'IT',
    'Engineering': 'Engineering',
    'not majoring': 'Undecided',
    'I wanted to do computer science but changed to certificate for financial reasons.': 'Computer Science',
    'used to be comp sci then switched to IT': 'Computer Science',
    'i did not change': 'Computer Science',
    'I did not change my major': 'Computer Science',
    'Architecture Program': 'Architecture',
    'no': 'Computer Science',
    'Computer programming': 'Computer Science',
    'changed from wanting to coach to IT': 'IT',
    'I have a degree, but wanted to attend ccm courses to get more experience with data analytics': 'Data Analytics',
    'Math': 'Math & Science',
    'none': 'Undecied',
    'EDAM sharetime': 'EDAM',
    'first choice': 'Computer Science',
    'Biology': 'Math & Science',
    'cybersecurity ': 'Cybersecurity',
    'Still majoring in engineering': 'Engineering',
    'Exercise Science': 'Exercise Science',
    'esl': 'ESL',
    'Cybersecurity ': 'Cybersecurity',
    "I didn't know how to go full into cybersecurity": 'Cybersecurity',
    'crim': 'Criminal Justice',
    'Graphic Design': 'Graphic Design',
    'came to ccm undecided for first year': 'Undecided',
    'idk': 'Undecided',
    'Psych': 'Psychology',
    'exercise science': 'Exercise Science',
    'First Choice':'Computer Science',
    'Unknown' : 'Undecided',
    'Mechanical Engineering': 'Engineering'
}

# Change the column
mydata_rename['Major'] = mydata_rename['Major'].replace(major)


mydata_rename['Major'].unique()
# Out:
# array(['Computer Science', nan, 'Business', 'Nursing', 'Soicial Science',
#        'Science', 'IT', 'Engineering', 'Radiography', 'History',
#        'Undecided', 'Criminal Justice ', 'Game Development',
#        'Criminal Justice', 'Architecture', 'Photography',
#        'Data Analytics', 'Math & Science', 'Undecied', 'EDAM',
#        'Cybersecurity', 'Game Design', 'Exercise Science', 'ESL',
#        'Graphic Design', 'Psychology'], dtype=object)

# %%
#check responses for race
mydata_rename['Race/ethnicity'].unique()
# Out:
# array(['White/Caucasian', 'Asian', 'Choose not to reply',
#        'Hispanic or Latino;White/Caucasian', 'Hispanic or Latino',
#        'American Indian/Native American/Alaska Native', 'Multi-Racial',
#        'American Indian/Native American/Alaska Native;Multi-Racial',
#        'Black/African American;White/Caucasian;Multi-Racial',
#        'Black/African American',
#        'Hispanic or Latino;American Indian/Native American/Alaska Native;Asian;Black/African American;Native Hawaiian/Other Pacific Islander;White/Caucasian',
#        'Hispanic or Latino;Black/African American',
#        'White/Caucasian;Multi-Racial',
#        'Asian;Native Hawaiian/Other Pacific Islander;White/Caucasian',
#        'Asian;White/Caucasian', 'Hispanic or Latino;Multi-Racial',
#        'Hispanic or Latino;American Indian/Native American/Alaska Native;White/Caucasian;Multi-Racial',
#        'American Indian/Native American/Alaska Native;Native Hawaiian/Other Pacific Islander;Multi-Racial',
# ...

# %%
#condence the race categories, first assign the change and then plug in the formula
race = {
    'White/Caucasian': 'White',
    'Asian': 'Asian',
    'Choose not to reply': 'Unknown',
    'Hispanic or Latino;White/Caucasian': 'Multi-Racial',
    'Hispanic or Latino': 'Hispanic',
    'American Indian/Native American/Alaska Native': 'Native American',
    'Multi-Racial': 'Multi-Racial', 
    'Black/African American;White/Caucasian;Multi-Racial': 'Multi-Racial',  
    'Black/African American': 'Black/African American',
    'Hispanic or Latino;American Indian/Native American/Alaska Native;Asian;Black/African American;Native Hawaiian/Other Pacific Islander;White/Caucasian':
        'Multi-Racial',
    'Hispanic or Latino;Black/African American': 'Multi-Racial',
    'White/Caucasian;Multi-Racial': 'Multi-Racial',
    'Asian;Native Hawaiian/Other Pacific Islander;White/Caucasian':
        'Multi-Racial',
    'Asian;White/Caucasian': 'Multi-Racial',
    'Hispanic or Latino;Multi-Racial': 'Multi-Racial',
    'Hispanic or Latino;American Indian/Native American/Alaska Native;White/Caucasian;Multi-Racial':
        'Multi-Racial', 
    'American Indian/Native American/Alaska Native;Native Hawaiian/Other Pacific Islander;Multi-Racial':
        'Multi-Racial', 
    'Asian;Native Hawaiian/Other Pacific Islander': 'Multi-Racial',
    'Hispanic or Latino;Black/African American;White/Caucasian':
        'Multi-Racial',
    'Asian;White/Caucasian;Multi-Racial': 'Multi-Racial',
    'White/Caucasian;Choose not to reply': 'White',
    'White/Caucasian;Multi-Racial;Choose not to reply': 'Multi-Racial',
    'Hispanic or Latino;White/Caucasian;Multi-Racial': 'Multi-Racial',
    'American Indian/Native American/Alaska Native;Multi-Racial': 'Multi-Racial'  
}


# Apply the mapping to the 'Race' column
mydata_rename['Race/ethnicity'] = mydata_rename['Race/ethnicity'].replace(race)

# %%
#begin to select unique rows so you dont loose any data in the process
unique_columns=mydata_rename

# %%
# Select specific columns by name and concate them horizontally with axis=1 on top would be axis=0
unique_columns = unique_columns.loc[:, 'Marketed Channel (CCM Website)': 'Impact (College Credit in High School)']
unique_columns = pd.concat([unique_columns, mydata_rename.loc[:, 'What degree program are you currently enrolled in?': 'Motivation (Personal Enrichment)']], axis=1)
unique_columns = pd.concat([unique_columns, mydata_rename.loc[:, 'Major': 'Age ']], axis=1)

# %%
unique_columns.columns
# Out:
# Index(['Marketed Channel (CCM Website)', 'Marketed Channel (Social Media)',
#        'Marketed Channel (Community Event)',
#        'Marketed Channel (Family member or friend)',
#        'Marketed Channel (Current CCM student)',
#        'Marketed Channel (CCM alumni)',
#        'Marketed Channel (High School Teacher)',
#        'Marketed Channel (High School Counselor)',
#        'Marketed Channel (In-app advertisement)', 'How You Heard (Employer)',
#        'How You Heard (Billboard)', 'How You Heard (Television)',
#        'How You Heard (Radio)', 'How You Heard (Home Mailer)',
#        'How You Heard (Other)', 'Impact (Affordable Cost)',
#        'Impact (Location/Convenience)', 'Impact (Choice of Programs)',
#        'Impact (Online Offerings)', 'Impact (Family/Friend Referral)',
#        'Impact (Faculty/Staff)', 'Impact (College Reputation)',
#        'Impact (Financial Aid)', 'Impact (Scholarships)',
# ...

# %%
unique_columns.to_csv('C:/Users/Hamza/Downloads/clean_entry_survey.csv')
